# %%
import pickle

# %%
thumbnails=pickle.load(open('bcc/image_thumbnails_new.pkl','rb'))

# %%
import matplotlib.pyplot as plt, matplotlib
matplotlib.rcParams['figure.dpi']=300
plt.imshow(thumbnails[26])
